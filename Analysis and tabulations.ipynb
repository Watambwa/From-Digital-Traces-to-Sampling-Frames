# %% [markdown]
# ### Analysis and tabulation of the frame

# %%
# Import required libraries
import pandas as pd

## Loading the dataset
companies = pd.read_csv('companies_with_urbanization.csv')

# Drop the specified columns
columns_to_drop = ['smod_year', 'smod_code', 'geocoded']
companies = companies.drop(columns=[col for col in columns_to_drop if col in companies.columns])

# Rename 'smod_label' column to 'urbanization'
companies = companies.rename(columns={'smod_label': 'urbanization'})

# Display the first few rows to verify
companies.head()
# Out:
#                                         name  \
# 0  Caroline Garments P/L t/a Caroline Safety
# 1             Pest Portal Zimbabwe (Pvt) Ltd
# 2                      Busy Bee Transcribing
# 3                   Athol Evans Hospita Home
# 4                                MEGA MARKET
#
#                                              address      city  \
# 0   26 Bon Accord Rd, Westondale, Bulawayo, Zimbabwe  Bulawayo
# 1  Office 11, 3D Building Strathaven Building, Av...    Harare
# 2    13 Ascot Road, Avondale West, Harare , Zimbabwe    Harare
# 3    P O Box Cr 70 Cranb Cranborne, Harare, Zimbabwe    Harare
# 4                      Target Area, Mutare, Zimbabwe    Mutare
#
#                  phone                                         source_url  \
# 0  +263 29 22776452003  https://www.zimbabweyp.com/company/88429/Carol...
# 1       07725933442007  https://www.zimbabweyp.com/company/104158/Pest...
# 2      0242-3089692012  https://www.zimbabweyp.com/company/106087/Busy...
# 3             570 8875  https://www.zimbabweyp.com/company/14492/Athol...
# 4         263-20-61517  https://www.zimbabweyp.com/company/4595/MEGA_M...
#
#     latitude  longitude    province  district  urbanization
# 0 -20.155479  28.550790    Bulawayo  Bulawayo  Urban centre
# 1 -17.792565  31.033528      Harare    Harare  Urban centre
# 2 -17.783362  31.024960      Harare    Harare  Urban centre
# 3 -17.847295  31.072463      Harare    Harare  Urban centre
# 4 -18.972991  32.671469  Manicaland    Mutare  Urban centre

# %% [markdown]
# ### Descriptive Statistics

# %%
# Create province by urbanization crosstab
province_urban = pd.crosstab(index=companies['province'],
                            columns=companies['urbanization'],
                            margins=True, margins_name="Total")

# Create district by urbanization crosstab
district_urban = pd.crosstab(index=companies['district'],
                            columns=companies['urbanization'],
                            margins=True, margins_name="Total")

# Sort districts by province for better readability
district_urban = district_urban.reindex(companies.drop_duplicates('district')
                                      .sort_values('province')['district']
                                      .tolist() + ['Total'])

# Save to Excel with multiple sheets
with pd.ExcelWriter('urbanization_analysis.xlsx', engine='openpyxl') as writer:
    province_urban.to_excel(writer, sheet_name='Province by Urbanization')
    district_urban.to_excel(writer, sheet_name='District by Urbanization')

    # Auto-adjust column widths
    for sheet_name in writer.sheets:
        worksheet = writer.sheets[sheet_name]
        # Get the max length of content in each column
        for col in worksheet.columns:
            max_length = 0
            column = col[0].column_letter  # Get the column name
            for cell in col:
                try:
                    if len(str(cell.value)) > max_length:
                        max_length = len(str(cell.value))
                except:
                    pass
            adjusted_width = (max_length + 2) * 1.2
            worksheet.column_dimensions[column].width = min(adjusted_width, 30)

print("Analysis saved to 'urbanization_analysis.xlsx'")
province_urban, district_urban  # Display the dataframes
# Out:
# Analysis saved to 'urbanization_analysis.xlsx'
# (urbanization         Dense urban cluster  Low density rural  Rural cluster  \
#  province
#  Bulawayo                              35                 46             23
#  Harare                                48                 93              0
#  Manicaland                            32                 42             12
#  Mashonaland Central                   32                 32              1
#  Mashonaland East                       3                 65             15
#  Mashonaland West                      26                104              9
#  Masvingo                               9                 32             17
#  Matabeleland North                   213                 37             13
#  Matabeleland South                    23                 16             12
#  Midlands                               6                 45              6
#  Total                                427                512            108
#
#  urbanization         Semi-dense urban cluster  Suburban or peri-urban  \
#  province
#  Bulawayo                                    0                     187
#  Harare                                      0                     754
#  Manicaland                                  9                      29
#  Mashonaland Central                         0                       9
#  Mashonaland East                            1                      14
#  Mashonaland West                            0                      50
#  Masvingo                                   11                      10
#  Matabeleland North                          0                       8
#  Matabeleland South                          0                       3
#  Midlands                                    0                      39
#  Total                                      21                    1103
#
#  urbanization         Urban centre  Very low density rural  Water  Total
#  province
#  Bulawayo                     3125                      20      0   3436
#  Harare                      24325                      94      0  25314
#  Manicaland                    252                      38      0    414
#  Mashonaland Central             0                      13      0     87
#  Mashonaland East              190                      36      0    324
#  Mashonaland West              202                      32      2    425
#  Masvingo                      107                      27      0    213
#  Matabeleland North              0                      26      7    304
#  Matabeleland South              0                      12      0     66
#  Midlands                      232                     266      0    594
#  Total                       28433                     564      9  31177  ,
#  urbanization    Dense urban cluster  Low density rural  Rural cluster  \
#  district
#  Bulawayo                       35.0               46.0           23.0
#  Harare                         48.0               93.0            0.0
#  Mutare                          9.0                5.0            4.0
#  Buhera                          3.0                7.0            0.0
#  Mutasa                          0.0                3.0            0.0
#  Chimanimani                     0.0                2.0            0.0
#  Chipinge                        5.0                4.0            1.0
#  Nyanga                          0.0               10.0            0.0
#  Makoni                         15.0               11.0            7.0
#  Shamva                          0.0                2.0            0.0
#  Guruve                          0.0                3.0            0.0
#  Mount Darwin                    0.0                0.0            1.0
#  Rushinga                        0.0                1.0            0.0
#  Bindura                        23.0                2.0            0.0
#  Centenary                       0.0                0.0            0.0
#  Mazowe                          9.0               24.0            0.0
#  Wedza                           0.0                7.0            0.0
#  Goromonzi                       0.0               22.0            4.0
#  Murehwa                         3.0               12.0            1.0
#  UMP                             0.0                1.0            2.0
#  Seke                            0.0                1.0            4.0
#  Mutoko                          0.0                5.0            0.0
#  Chikomba                        0.0                5.0            0.0
#  Marondera                       0.0               12.0            4.0
#  Kadoma                          3.0                3.0            0.0
#  Hurungwe                        1.0                8.0            0.0
#  Kariba                         18.0                1.0            2.0
#  Makonde                         0.0               11.0            1.0
#  Chegutu                         0.0               64.0            0.0
#  Zvimba                          4.0               17.0            6.0
#  Masvingo                        0.0               13.0            6.0
#  Bikita                          0.0                4.0            0.0
#  Zaka                            0.0                0.0            0.0
#  Gutu                            0.0                6.0            3.0
#  Chivi                           0.0                9.0            5.0
#  Chiredzi                        9.0                0.0            2.0
#  Mwenezi                         0.0                0.0            1.0
#  Lupane                          0.0                1.0            0.0
#  Bubi                            0.0                7.0            6.0
#  Nkayi                           0.0                5.0            0.0
#  Binga                           0.0                1.0            0.0
#  Hwange                        213.0                9.0            3.0
#  Tsholotsho                      0.0                1.0            0.0
#  Umguza                          0.0               13.0            4.0
#  Umzingwane                      0.0                3.0            8.0
#  Mangwe (South)                  2.0                0.0            0.0
#  Matobo                          0.0               12.0            0.0
#  Insiza                          0.0                1.0            2.0
#  Beitbridge                     17.0                0.0            0.0
#  Gwanda                          4.0                0.0            2.0
#  Gokwe South                     5.0                4.0            0.0
#  Kwekwe                          1.0               11.0            0.0
#  Zvishavane                      0.0               11.0            0.0
#  Chirumhanzu                     0.0                0.0            2.0
#  Shurugwi                        0.0               11.0            0.0
#  Gweru                           0.0                7.0            0.0
#  Mberengwa                       0.0                1.0            4.0
#  NaN                             NaN                NaN            NaN
#  Total                         427.0              512.0          108.0
#
#  urbanization    Semi-dense urban cluster  Suburban or peri-urban  \
#  district
#  Bulawayo                             0.0                   187.0
#  Harare                               0.0                   754.0
#  Mutare                               0.0                    16.0
#  Buhera                               2.0                     0.0
#  Mutasa                               2.0                     0.0
#  Chimanimani                          0.0                    10.0
#  Chipinge                             0.0                     0.0
#  Nyanga                               5.0                     1.0
#  Makoni                               0.0                     2.0
#  Shamva                               0.0                     0.0
#  Guruve                               0.0                     0.0
#  Mount Darwin                         0.0                     0.0
#  Rushinga                             0.0                     0.0
#  Bindura                              0.0                     1.0
#  Centenary                            0.0                     0.0
#  Mazowe                               0.0                     8.0
#  Wedza                                0.0                     0.0
#  Goromonzi                            0.0                     6.0
#  Murehwa                              1.0                     0.0
#  UMP                                  0.0                     0.0
#  Seke                                 0.0                     0.0
#  Mutoko                               0.0                     0.0
#  Chikomba                             0.0                     6.0
#  Marondera                            0.0                     2.0
#  Kadoma                               0.0                     2.0
#  Hurungwe                             0.0                     3.0
#  Kariba                               0.0                     8.0
#  Makonde                              0.0                    10.0
#  Chegutu                              0.0                     7.0
#  Zvimba                               0.0                    20.0
#  Masvingo                             0.0                     2.0
#  Bikita                               0.0                     6.0
#  Zaka                                 6.0                     0.0
#  Gutu                                 0.0                     0.0
#  Chivi                                0.0                     0.0
#  Chiredzi                             5.0                     1.0
#  Mwenezi                              0.0                     1.0
#  Lupane                               0.0                     0.0
#  Bubi                                 0.0                     0.0
#  Nkayi                                0.0                     0.0
#  Binga                                0.0                     0.0
#  Hwange                               0.0                     8.0
#  Tsholotsho                           0.0                     0.0
#  Umguza                               0.0                     0.0
#  Umzingwane                           0.0                     0.0
#  Mangwe (South)                       0.0                     0.0
#  Matobo                               0.0                     2.0
#  Insiza                               0.0                     0.0
#  Beitbridge                           0.0                     1.0
#  Gwanda                               0.0                     0.0
#  Gokwe South                          0.0                     0.0
#  Kwekwe                               0.0                    21.0
#  Zvishavane                           0.0                     1.0
#  Chirumhanzu                          0.0                     0.0
#  Shurugwi                             0.0                     0.0
#  Gweru                                0.0                    17.0
#  Mberengwa                            0.0                     0.0
#  NaN                                  NaN                     NaN
#  Total                               21.0                  1103.0
#
#  urbanization    Urban centre  Very low density rural  Water    Total
#  district
#  Bulawayo              3125.0                    20.0    0.0   3436.0
#  Harare               24325.0                    94.0    0.0  25314.0
#  Mutare                 252.0                    12.0    0.0    298.0
#  Buhera                   0.0                     2.0    0.0     14.0
#  Mutasa                   0.0                     2.0    0.0      7.0
#  Chimanimani              0.0                     1.0    0.0     13.0
#  Chipinge                 0.0                     7.0    0.0     17.0
#  Nyanga                   0.0                    11.0    0.0     27.0
#  Makoni                   0.0                     3.0    0.0     38.0
#  Shamva                   0.0                     1.0    0.0      3.0
#  Guruve                   0.0                     0.0    0.0      3.0
#  Mount Darwin             0.0                     4.0    0.0      5.0
#  Rushinga                 0.0                     0.0    0.0      1.0
#  Bindura                  0.0                     5.0    0.0     31.0
#  Centenary                0.0                     1.0    0.0      1.0
#  Mazowe                   0.0                     2.0    0.0     43.0
#  Wedza                    0.0                    10.0    0.0     17.0
#  Goromonzi              125.0                     3.0    0.0    160.0
#  Murehwa                  0.0                     1.0    0.0     18.0
#  UMP                      0.0                     0.0    0.0      3.0
#  Seke                     0.0                     0.0    0.0      5.0
#  Mutoko                   0.0                     2.0    0.0      7.0
#  Chikomba                 0.0                     2.0    0.0     13.0
#  Marondera               65.0                    18.0    0.0    101.0
#  Kadoma                  45.0                     4.0    0.0     57.0
#  Hurungwe                 0.0                     5.0    0.0     17.0
#  Kariba                   0.0                     3.0    0.0     32.0
#  Makonde                 51.0                     2.0    0.0     75.0
#  Chegutu                 49.0                     1.0    0.0    121.0
#  Zvimba                  57.0                    17.0    2.0    123.0
#  Masvingo               107.0                     7.0    0.0    135.0
#  Bikita                   0.0                     1.0    0.0     11.0
#  Zaka                     0.0                     1.0    0.0      7.0
#  Gutu                     0.0                     6.0    0.0     15.0
#  Chivi                    0.0                     0.0    0.0     14.0
#  Chiredzi                 0.0                    11.0    0.0     28.0
#  Mwenezi                  0.0                     1.0    0.0      3.0
#  Lupane                   0.0                     1.0    0.0      2.0
#  Bubi                     0.0                     2.0    0.0     15.0
#  Nkayi                    0.0                     0.0    0.0      5.0
#  Binga                    0.0                     5.0    0.0      6.0
#  Hwange                   0.0                    15.0    7.0    255.0
#  Tsholotsho               0.0                     3.0    0.0      4.0
#  Umguza                   0.0                     0.0    0.0     17.0
#  Umzingwane               0.0                     2.0    0.0     13.0
#  Mangwe (South)           0.0                     2.0    0.0      4.0
#  Matobo                   0.0                     4.0    0.0     18.0
#  Insiza                   0.0                     0.0    0.0      3.0
#  Beitbridge               0.0                     3.0    0.0     21.0
#  Gwanda                   0.0                     1.0    0.0      7.0
#  Gokwe South              0.0                     0.0    0.0      9.0
#  Kwekwe                  80.0                   244.0    0.0    357.0
#  Zvishavane               1.0                     3.0    0.0     16.0
#  Chirumhanzu              0.0                     1.0    0.0      3.0
#  Shurugwi                 0.0                     7.0    0.0     18.0
#  Gweru                  151.0                     9.0    0.0    184.0
#  Mberengwa                0.0                     2.0    0.0      7.0
#  NaN                      NaN                     NaN    NaN      NaN
#  Total                28433.0                   564.0    9.0  31177.0  )
