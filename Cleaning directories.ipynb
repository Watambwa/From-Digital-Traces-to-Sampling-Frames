# %% [markdown]
# ### Loading directory lists

# %%
import pandas as pd

# Load the most recent CSV file
directories = pd.read_csv('zimbabwe_company_directories_web.csv')
directories
# Out:
#      number                                              title  \
# 0         1         Zimbabwe Business Directory 2025 | AFRIKTA
# 1         2    Parco nazionale e riserva di Wrangell-St. Elias
# 2         3      Trade With Vikas by Vikas Ola - appadvice.com
# 3         4                 ‎Trade With Vikas on the App Store
# 4         5         Google Chrome for Google Chrome - Download
# ..      ...                                                ...
# 104     105  in company with”和“ in the company of”的区别是什么_百度...
# 105     106                             "company"怎么变复数？？？_百度知道
# 106     107                accompany companion company的区别_百度知道
# 107     108                          江苏省企业全链通综合服务平台怎么填报 - 百度知道
# 108     109                               江苏受益人备案操作填报流程 - 百度知道
#
#                                                    url  \
# 0      https://afrikta.com/listing-locations/zimbabwe/
# 1    https://antropocene.it/2021/10/23/parco-nazion...
# 2    https://appadvice.com/app/trade-with-vikas/660...
# 3    https://apps.apple.com/in/app/trade-with-vikas...
# 4                      https://chrome.en.softonic.com/
# ..                                                 ...
# 104  https://zhidao.baidu.com/question/436616749019...
# 105   https://zhidao.baidu.com/question/501890641.html
# 106    https://zhidao.baidu.com/question/50954363.html
# 107  https://zhidao.baidu.com/question/637813618701...
# 108  https://zhidao.baidu.com/question/932543063403...
#
#                      domain      source  \
# 0               afrikta.com  web_search
# 1            antropocene.it  web_search
# 2             appadvice.com  web_search
# 3            apps.apple.com  web_search
# 4    chrome.en.softonic.com  web_search
# ..                      ...         ...
# 104        zhidao.baidu.com  web_search
# 105        zhidao.baidu.com  web_search
# 106        zhidao.baidu.com  web_search
# 107        zhidao.baidu.com  web_search
# 108        zhidao.baidu.com  web_search
#
#                                       query   country search_date
# 0                     yellow pages zimbabwe  Zimbabwe   2/12/2025
# 1    zimbabweypzimbabwe suppliers directory  Zimbabwe   2/12/2025
# 2    zimbabweypzimbabwe suppliers directory  Zimbabwe   2/12/2025
# 3    zimbabweypzimbabwe suppliers directory  Zimbabwe   2/12/2025
# 4    zimbabweypzimbabwe suppliers directory  Zimbabwe   2/12/2025
# ..                                      ...       ...         ...
# 104         company directories in zimbabwe  Zimbabwe   2/12/2025
# 105         company directories in zimbabwe  Zimbabwe   2/12/2025
# 106         company directories in zimbabwe  Zimbabwe   2/12/2025
# 107             business directory zimbabwe  Zimbabwe   2/12/2025
# 108             business directory zimbabwe  Zimbabwe   2/12/2025
#
# [109 rows x 8 columns]

# %%
import re
from urllib.parse import urljoin, urlparse
import time
from concurrent.futures import ThreadPoolExecutor, as_completed
import requests
from bs4 import BeautifulSoup

def is_company_listing_page(soup, url):
    """
    Check if the page contains a list of companies.
    Returns a confidence score (0-1) and the type of listing found.
    """
    text = soup.get_text().lower()

    # Check for common indicators of company listings
    indicators = {
        'table': len(soup.find_all('table')) > 0,
        'list_items': len(soup.find_all(['ul', 'ol'])) > 2,
        'keywords': any(word in text for word in [
            'company', 'business', 'directory', 'listings', 'enterprises',
            'corporat', 'industr', 'limited', 'ltd', 'pty', 'inc', 'llc'
        ]),
        'links': len(soup.find_all('a', href=True)) > 10
    }

    # Calculate confidence score
    confidence = sum(1 for v in indicators.values() if v) / len(indicators)
    return confidence > 0.5

def find_company_listings(url, max_depth=2, current_depth=0):
    """
    Recursively search for pages containing company listings.
    Returns a list of URLs that likely contain company listings.
    """
    if current_depth > max_depth:
        return []

    try:
        headers = {'User-Agent': 'Mozilla/5.0'}
        response = requests.get(url, headers=headers, timeout=10)
        soup = BeautifulSoup(response.text, 'html.parser')

        # Check if current page is a listing
        if is_company_listing_page(soup, url):
            return [url]

        # If not, look for links that might lead to listings
        listing_urls = []
        for link in soup.find_all('a', href=True):
            href = link['href']
            if not href or href.startswith(('javascript:', 'mailto:', 'tel:', '#')):
                continue

            # Handle relative URLs
            full_url = urljoin(url, href)

            # Avoid duplicate checks and non-HTTP URLs
            if full_url == url or not full_url.startswith(('http://', 'https://')):
                continue

            # Check if URL looks like it might contain listings
            path = urlparse(full_url).path.lower()
            if any(term in path for term in ['company', 'business', 'directory', 'listings', 'members', 'membership']):
                listing_urls.append(full_url)

        # Recursively check potential listing URLs
        results = []
        for listing_url in listing_urls[:5]:  # Limit to top 5 to avoid too many requests
            try:
                results.extend(find_company_listings(listing_url, max_depth, current_depth + 1))
            except:
                continue
            time.sleep(1)  # Be nice to the server

        return list(set(results))  # Remove duplicates

    except Exception as e:
        print(f"Error processing {url}: {str(e)}")
        return []

def process_url(row):
    """Process a single URL and return updated row with found listings"""
    url = row['url']
    print(f"Processing: {url}")

    try:
        listings = find_company_listings(url)
        if listings:
            row['listing_urls'] = ' | '.join(listings)
            row['has_listings'] = True
        else:
            row['listing_urls'] = ''
            row['has_listings'] = False
    except Exception as e:
        print(f"Error with {url}: {e}")
        row['listing_urls'] = ''
        row['has_listings'] = False

    return row

# Process URLs in parallel (adjust max_workers as needed)
def process_all_urls(df, max_workers=3):
    """Process all URLs in the DataFrame"""
    results = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = [executor.submit(process_url, row) for _, row in df.iterrows()]
        for future in as_completed(futures):
            results.append(future.result())
            print(f"Completed: {len(results)}/{len(df)}")

    return pd.DataFrame(results)

# Run the processing (this may take some time)
print("Starting URL processing...")
directories_processed = process_all_urls(directories)

# Save results
directories_processed.to_csv('directories_with_listings.csv', index=False)
print("Processing complete. Results saved to 'directories_with_listings.csv'")

# Show results
print("\nSummary of findings:")
print(f"Total directories processed: {len(directories_processed)}")
print(f"Directories with listings: {directories_processed['has_listings'].sum()}")
# Out:
# Starting URL processing...
# Processing: https://afrikta.com/listing-locations/zimbabwe/
# Processing: https://antropocene.it/2021/10/23/parco-nazionale-e-riserva-di-wrangell-st-elias/
# Processing: https://appadvice.com/app/trade-with-vikas/6608975480
# Processing: https://apps.apple.com/in/app/trade-with-vikas/id6608975480Completed: 1/109
#
# Processing: https://chrome.en.softonic.com/Completed: 2/109
#
# Processing: https://chrome.en.softonic.com/download
# Completed: 3/109
# Processing: https://classplusapp.com/w/tradewithvikasCompleted: 4/109
#
# Processing: https://eduniversal-ranking.com/gem-alpine-business-school-ranking.htmlCompleted: 5/109
#
# Processing: https://en.wikipedia.org/wiki/Zimbabwe
# Completed: 6/109
# Processing: https://forum.wordreference.com/threads/company-is-are.2961868/Completed: 7/109
#
# Processing: https://forum.wordreference.com/threads/in-at-the-company.215026/
# Completed: 8/109
# Processing: https://forum.wordreference.com/threads/m-s-followed-by-a-company-name.1606232/Completed: 9/109
#
# Processing: https://forum.wordreference.com/threads/who-is-company-name-or-who-are-company-name.3469707/
# Completed: 10/109
# Processing: https://gizmodo.com/download/google-chromeCompleted: 11/109
#
# Processing: https://google-chrome.en.lo4d.com/windows
# Completed: 12/109
# Processing: https://google-chrome.en.uptodown.com/windows
# Completed: 13/109
# Processing: https://isnca.org/it/cosa-cè-di-così-speciale-nel-wrangell-st-elias/Completed: 14/109
#
# Processing: https://it.knowledgr.com/10726474/WrangellParcoNazionaleDiSEliasERiservaCompleted: 15/109
#
# Processing: https://it.wikipedia.org/wiki/Parco_nazionale_e_riserva_di_Wrangell-St._EliasCompleted: 16/109
#
# Processing: https://linktr.ee/tradewithvikasCompleted: 17/109
#
# Processing: https://mbagradschools.com/school/gem-alpine-business-schoolCompleted: 18/109
#
# Processing: https://news.co.zw/Completed: 19/109
#
# Processing: https://ontheworldmap.com/zimbabwe/
# Completed: 20/109
# Processing: https://peapix.com/bing/54147Completed: 21/109
#
# Processing: https://pellebranden.com/blog/iphone-13-pro-max-graphiteCompleted: 22/109
#
# Processing: https://play.google.com/store/apps/details?id=co.ted.jytfr&hl=en-USCompleted: 23/109
#
# Processing: https://support.google.com/chrome/answer/95346?hl=en&co=GENIE.Platform=DesktopCompleted: 24/109
#
# Processing: https://sur.ly/i/yellowpages.co.zw/Completed: 25/109
#
# Error processing https://news.co.zw/: HTTPSConnectionPool(host='news.co.zw', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000002045DDB1310>, 'Connection to news.co.zw timed out. (connect timeout=10)'))
# Processing: https://swappa.com/listings/apple-iphone-13-pro-max?color=graphite
# Completed: 26/109
# Processing: https://thedirectory.co.zw/
# Completed: 27/109
# Processing: https://thedirectory.co.zw/listings.cfm?Smartpages=Yellow+Pages+ZimbabweCompleted: 28/109
#
# Processing: https://thezimbabwemail.com/
# Completed: 29/109
# Processing: https://wanderlog.com/it/list/geoCategory/1599352/parco-nazionale-e-riserva-di-wrangell-st-elias-skyline-i-edifici-più-iconici-e-le-migliori-viste-in-parco-nazionale-e-riserva-di-wrangell-st-eliasCompleted: 30/109
#
# Processing: https://wikiusa.org/it/parco-nazionale-di-wrangell-st-eliasCompleted: 31/109
#
# Processing: https://www.aljazeera.com/where/zimbabweCompleted: 32/109
#
# Processing: https://www.allianz-assistance.ie/Completed: 33/109
#
# Processing: https://www.allianz-assistance.ie/help-and-advice.htmlCompleted: 34/109
#
# Processing: https://www.allianz-assistance.ie/help-and-advice/claim-centre.htmlCompleted: 35/109
#
# Processing: https://www.allianz-assistance.ie/help-and-advice/contact-us.htmlCompleted: 36/109
#
# Processing: https://www.allianz-assistance.ie/help-and-advice/policy-info.htmlCompleted: 37/109
#
# Processing: https://www.allianz-assistance.ie/travel-insurance-quote.html
# Completed: 38/109
# Processing: https://www.allianz-assistance.ie/travel-insurance.htmlCompleted: 39/109
#
# Processing: https://www.allianz-assistance.ie/travel-insurance/annual-multi-trip-travel-insurance.html
# Completed: 40/109
# Processing: https://www.allianz-assistance.ie/travel-insurance/destinations/europe-travel-insurance.html
# Completed: 41/109
# Processing: https://www.allianz-assistance.ie/travel-insurance/single-trip-travel-insurance.html
# Completed: 42/109
# Processing: https://www.alltrails.com/it-it/parchi/us/alaska/wrangell-st-elias-national-park-preserve/waterfallCompleted: 43/109
#
# Processing: https://www.amazon.com/Apple-iPhone-13-Pro-Graphite/dp/B09LP77GDL
# Completed: 44/109
# Processing: https://www.amazon.com/Apple-iPhone-Pro-256GB-Graphite/dp/B09LPPRJDYCompleted: 45/109
#
# Processing: https://www.amba-bga.com/schools/grenoble-cole-de-management
# Completed: 46/109
# Processing: https://www.appbrain.com/app/trade-with-vikas/co.ted.jytfrCompleted: 47/109
#
# Processing: https://www.apple.com/us-edu/shop/product/FLTP3LL/A/refurbished-iphone-13-pro-128gb-graphite-unlockedCompleted: 48/109
#
# Processing: https://www.backmarket.com/en-us/l/iphone-13-pro-graphite/5d6e4bd7-49c1-433c-b86d-8f66c80250bb?msockid=037034a2cfaa68f31c442214ce5969c2
# Completed: 49/109
# Processing: https://www.bestbuy.com/site/searchpage.jsp?id=pcat17071&st=iphone+13+graphiteCompleted: 50/109
#
# Processing: https://www.britannica.com/place/ZimbabweCompleted: 51/109
#
# Processing: https://www.classifieds.co.zw/directoryCompleted: 52/109
#
# Processing: https://www.cybo.com/zimbabwe/Completed: 53/109
#
# Processing: https://www.distancelearningportal.com/universities/997/gem-alpine-business-school.htmlCompleted: 54/109
#
# Processing: https://www.gembusinessschool.com.ng/Completed: 55/109
#
# Processing: https://www.google.com/chrome/Completed: 56/109
#
# Processing: https://www.google.com/chrome/what-you-make-of-it/Completed: 57/109
#
# Processing: https://www.google.com/intl/en_uk/chrome/Completed: 58/109
#
# Error processing https://www.bestbuy.com/site/searchpage.jsp?id=pcat17071&st=iphone+13+graphite: HTTPSConnectionPool(host='www.bestbuy.com', port=443): Read timed out. (read timeout=10)
# Processing: https://www.grenoble-em.com/en
# Completed: 59/109
# Processing: https://www.grenoble-em.com/en/news/gem-becomes-gem-alpine-business-school-a-new-identity-for-a-new-ambitionCompleted: 60/109
#
# Processing: https://www.indusappstore.com/apps/education/trade-with-vikas/co.ted.jytfr/?page=details&id=co.ted.jytfrCompleted: 61/109
#
# Processing: https://www.instagram.com/popular/alpine-business-school/Completed: 62/109
#
# Processing: https://www.mastersportal.com/universities/997/gem-alpine-business-school.htmlCompleted: 63/109
#
# Processing: https://www.nationsonline.org/oneworld/zimbabwe.htmCompleted: 64/109
#
# Processing: https://www.newsnow.co.uk/h/World+News/Africa/Zimbabwe
# Completed: 65/109
# Processing: https://www.phdportal.com/universities/997/gem-alpine-business-school.htmlCompleted: 66/109
#
# Processing: https://www.target.com/p/apple-iphone-13-pro-5g-pre-owned-unlocked-128gb-gsm-cdma-graphite/-/A-90296531Completed: 67/109
#
# Processing: https://www.techspot.com/downloads/4718-google-chrome.htmlCompleted: 68/109
#
# Processing: https://www.tradewithvikas.in/Completed: 69/109
#
# Processing: https://www.tradewithvikas.in/coursesCompleted: 70/109
#
# Processing: https://www.tripadvisor.it/Attraction_Review-g143056-d4573297-Reviews-Wrangell_St_Elias_National_Park_Preserve_Visitor_Center-Wrangell_St_Elias_Nationa.htmlCompleted: 71/109
#
# Processing: https://www.usingenglish.com/articles/100-most-useful-phrases-for-ending-emails.htmlCompleted: 72/109
#
# Processing: https://www.usingenglish.com/comprehension/42.htmlCompleted: 73/109
#
# Processing: https://www.usingenglish.com/files/pdf/business-english-describing-companies.pdfCompleted: 74/109
#
# Processing: https://www.usingenglish.com/files/pdf/present-simple-and-continuous-for-describing-your-company-and-job.pdfCompleted: 75/109
#
# Processing: https://www.usingenglish.com/forum/threads/a-person-who-serves-drinks-and-food.249359/Completed: 76/109
#
# Processing: https://www.usingenglish.com/forum/threads/companies-vs-companys.59631/Completed: 77/109
#
# Processing: https://www.usingenglish.com/forum/threads/do-you-need-the-in-front-of-an-organization-name.117340/Completed: 78/109
#
# Processing: https://www.usingenglish.com/forum/threads/vocab-grammar-test-all-in-one-my-answers-part-1.173608/Completed: 79/109
#
# Processing: https://www.usingenglish.com/teachers/articles/list-regular-plurals-ending-in-s-es-ies.htmlCompleted: 80/109
#
# Processing: https://www.usingenglish.com/teachers/lesson-plans/view-business-english-describing-companies/Completed: 81/109
#
# Processing: https://www.viaggi-usa.it/wrangell-st-elias-national-park/Completed: 82/109
#
# Processing: https://www.walmart.com/ip/Apple-iPhone-13-Pro-A2483-128GB-Graphite-US-Model-Factory-Unlocked-Cell-Phone-Excellent-Condition/1275454808Completed: 83/109
#
# Processing: https://www.worldatlas.com/maps/zimbabweCompleted: 84/109
#
# Processing: https://www.zimbabweyp.com/browse-business-directory
# Completed: 85/109
# Processing: https://www.zhihu.com/question/19581923Completed: 86/109
#
# Processing: https://www.zhihu.com/question/24837502Completed: 87/109
#
# Processing: https://www.zhihu.com/question/379426445Completed: 88/109
#
# Processing: https://www.zhihu.com/question/600313078
# Completed: 89/109
# Processing: https://www.zhihu.com/question/7439649051Completed: 90/109
#
# Processing: https://www.zhihu.com/question/9991552982
# Completed: 91/109
# Processing: https://www.zimbabwesituation.com/Completed: 92/109
#
# Processing: https://www.zimplaza.co.zw/listing/zimyellowpage/
# Completed: 93/109
# Processing: https://www.zimyellow.com/Completed: 94/109
#
# Processing: https://www.zimyellow.com/categoriesCompleted: 95/109
#
# Processing: https://www.zimyellowpage.com/listings/category/ernest-young-zimbabweCompleted: 96/109
#
# Processing: https://zhidao.baidu.com/question/1442736554551286019.htmlCompleted: 97/109
#
# Error processing https://www.zimyellow.com/categories: HTTPSConnectionPool(host='www.zimyellow.com', port=443): Read timed out. (read timeout=10)
# Processing: https://zhidao.baidu.com/question/1638364605614234300.html
# Completed: 98/109
# Processing: https://zhidao.baidu.com/question/1651293663139400260.htmlCompleted: 99/109
#
# Processing: https://zhidao.baidu.com/question/1843356132244347660.htmlCompleted: 100/109
#
# Processing: https://zhidao.baidu.com/question/275787749460138285.htmlCompleted: 101/109
#
# Processing: https://zhidao.baidu.com/question/436616749019328772.htmlCompleted: 102/109
#
# Processing: https://zhidao.baidu.com/question/501890641.htmlCompleted: 103/109
#
# Processing: https://zhidao.baidu.com/question/50954363.htmlCompleted: 104/109
#
# Processing: https://zhidao.baidu.com/question/637813618701195724.htmlCompleted: 105/109
#
# Processing: https://zhidao.baidu.com/question/932543063403857659.htmlCompleted: 106/109
#
# Completed: 107/109
# Completed: 108/109
# Completed: 109/109
# Processing complete. Results saved to 'directories_with_listings.csv'
#
# Summary of findings:
# Total directories processed: 109
# Directories with listings: 46
